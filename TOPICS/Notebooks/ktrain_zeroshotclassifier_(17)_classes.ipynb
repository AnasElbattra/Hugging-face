# %% [markdown]
# # **5**

# %%
df2_pred5 = find_top_categories_for_lists(doc_prb , 5)

# %%
df2_pred5
# Out:
# [['science and technology',
#   'society',
#   'education',
#   'human interest',
#   'lifestyle and leisure'],
#  ['education',
#   'religion and belief',
#   'society',
#   'human interest',
#   'lifestyle and leisure'],
#  ['lifestyle and leisure',
#   'arts, culture, entertainment and media',
#   'health',
#   'environment',
#   'labour'],
#  ['education',
#   'human interest',
#   'science and technology',
#   'health',
#   'society'],
#  ['arts, culture, entertainment and media',
#   'sport',
#   'society',
#   'lifestyle and leisure',
#   'science and technology'],
#  ['human interest',
#   'lifestyle and leisure',
#   'arts, culture, entertainment and media',
#   'health',
#   'conflict, war and peace'],
#  ['economy, business and finance',
#   'society',
#   'politics',
#   'human interest',
#   'labour'],
#  ['disaster, accident and emergency incident',
#   'weather',
#   'society',
#   'human interest',
#   'environment'],
#  ['politics',
#   'society',
#   'religion and belief',
#   'human interest',
#   'conflict, war and peace'],
#  ['conflict, war and peace',
#   'politics',
#   'society',
#   'disaster, accident and emergency incident',
#   'human interest'],
#  ['society', 'environment', 'science and technology', 'politics', 'labour'],
#  ['sport',
#   'human interest',
#   'economy, business and finance',
#   'arts, culture, entertainment and media',
#   'society'],
#  ['conflict, war and peace',
#   'religion and belief',
#   'disaster, accident and emergency incident',
#   'society',
#   'politics'],
#  ['weather',
#   'society',
#   'human interest',
#   'environment',
#   'disaster, accident and emergency incident'],
#  ['economy, business and finance',
#   'society',
#   'crime, law and justice',
#   'human interest',
#   'conflict, war and peace'],
#  ['religion and belief',
#   'arts, culture, entertainment and media',
#   'human interest',
#   'crime, law and justice',
#   'society'],
#  ['health',
#   'sport',
#   'lifestyle and leisure',
#   'human interest',
#   'arts, culture, entertainment and media'],
#  ['health',
#   'human interest',
#   'society',
#   'science and technology',
#   'environment'],
#  ['politics',
#   'society',
#   'conflict, war and peace',
#   'human interest',
#   'disaster, accident and emergency incident'],
#  ['human interest',
#   'crime, law and justice',
#   'disaster, accident and emergency incident',
#   'society',
#   'arts, culture, entertainment and media'],
#  ['religion and belief',
#   'conflict, war and peace',
#   'education',
#   'society',
#   'disaster, accident and emergency incident'],
#  ['politics',
#   'society',
#   'conflict, war and peace',
#   'human interest',
#   'labour'],
#  ['crime, law and justice',
#   'religion and belief',
#   'society',
#   'conflict, war and peace',
#   'human interest'],
#  ['religion and belief',
#   'human interest',
#   'conflict, war and peace',
#   'society',
#   'crime, law and justice'],
#  ['politics',
#   'environment',
#   'society',
#   'human interest',
#   'conflict, war and peace'],
#  ['human interest',
#   'health',
#   'science and technology',
#   'disaster, accident and emergency incident',
#   'society'],
#  ['sport',
#   'human interest',
#   'arts, culture, entertainment and media',
#   'health',
#   'economy, business and finance'],
#  ['politics',
#   'society',
#   'economy, business and finance',
#   'labour',
#   'conflict, war and peace'],
#  ['human interest',
#   'economy, business and finance',
#   'society',
#   'politics',
#   'arts, culture, entertainment and media'],
#  ['science and technology',
#   'human interest',
#   'environment',
#   'education',
#   'disaster, accident and emergency incident'],
#  ['crime, law and justice', 'society', 'human interest', 'labour', 'politics'],
#  ['environment',
#   'crime, law and justice',
#   'science and technology',
#   'society',
#   'disaster, accident and emergency incident'],
#  ['society',
#   'arts, culture, entertainment and media',
#   'economy, business and finance',
#   'politics',
#   'human interest'],
#  ['human interest',
#   'arts, culture, entertainment and media',
#   'lifestyle and leisure',
#   'society',
#   'education'],
#  ['society',
#   'crime, law and justice',
#   'lifestyle and leisure',
#   'politics',
#   'human interest'],
#  ['arts, culture, entertainment and media',
#   'human interest',
#   'society',
#   'environment',
#   'lifestyle and leisure'],
#  ['sport',
#   'human interest',
#   'society',
#   'arts, culture, entertainment and media',
#   'economy, business and finance'],
#  ['health',
#   'science and technology',
#   'disaster, accident and emergency incident',
#   'environment',
#   'society'],
#  ['human interest',
#   'science and technology',
#   'society',
#   'arts, culture, entertainment and media',
#   'labour'],
#  ['economy, business and finance',
#   'science and technology',
#   'society',
#   'politics',
#   'human interest'],
#  ['economy, business and finance',
#   'society',
#   'lifestyle and leisure',
#   'arts, culture, entertainment and media',
#   'weather'],
#  ['conflict, war and peace',
#   'politics',
#   'society',
#   'crime, law and justice',
#   'human interest'],
#  ['human interest', 'conflict, war and peace', 'society', 'labour', 'health'],
#  ['sport',
#   'arts, culture, entertainment and media',
#   'science and technology',
#   'disaster, accident and emergency incident',
#   'environment'],
#  ['crime, law and justice',
#   'society',
#   'human interest',
#   'politics',
#   'conflict, war and peace'],
#  ['human interest',
#   'health',
#   'education',
#   'science and technology',
#   'disaster, accident and emergency incident'],
#  ['weather',
#   'disaster, accident and emergency incident',
#   'human interest',
#   'society',
#   'environment'],
#  ['economy, business and finance',
#   'labour',
#   'society',
#   'health',
#   'disaster, accident and emergency incident'],
#  ['lifestyle and leisure',
#   'arts, culture, entertainment and media',
#   'environment',
#   'sport',
#   'disaster, accident and emergency incident'],
#  ['environment',
#   'conflict, war and peace',
#   'politics',
#   'human interest',
#   'society'],
#  ['economy, business and finance',
#   'science and technology',
#   'disaster, accident and emergency incident',
#   'labour',
#   'crime, law and justice'],
#  ['conflict, war and peace',
#   'disaster, accident and emergency incident',
#   'politics',
#   'society',
#   'human interest'],
#  ['crime, law and justice',
#   'economy, business and finance',
#   'society',
#   'arts, culture, entertainment and media',
#   'environment'],
#  ['health',
#   'environment',
#   'society',
#   'science and technology',
#   'disaster, accident and emergency incident'],
#  ['economy, business and finance',
#   'society',
#   'conflict, war and peace',
#   'human interest',
#   'health'],
#  ['human interest',
#   'society',
#   'lifestyle and leisure',
#   'environment',
#   'arts, culture, entertainment and media'],
#  ['science and technology',
#   'labour',
#   'human interest',
#   'environment',
#   'society'],
#  ['health',
#   'education',
#   'society',
#   'human interest',
#   'crime, law and justice'],
#  ['politics',
#   'society',
#   'environment',
#   'science and technology',
#   'human interest'],
#  ['disaster, accident and emergency incident',
#   'society',
#   'environment',
#   'crime, law and justice',
#   'labour'],
#  ['politics',
#   'health',
#   'human interest',
#   'disaster, accident and emergency incident',
#   'society'],
#  ['education',
#   'human interest',
#   'labour',
#   'economy, business and finance',
#   'society'],
#  ['religion and belief',
#   'politics',
#   'conflict, war and peace',
#   'society',
#   'disaster, accident and emergency incident'],
#  ['labour',
#   'politics',
#   'society',
#   'economy, business and finance',
#   'human interest'],
#  ['human interest',
#   'health',
#   'arts, culture, entertainment and media',
#   'education',
#   'society'],
#  ['health',
#   'politics',
#   'society',
#   'disaster, accident and emergency incident',
#   'human interest'],
#  ['science and technology',
#   'arts, culture, entertainment and media',
#   'disaster, accident and emergency incident',
#   'economy, business and finance',
#   'environment'],
#  ['health',
#   'science and technology',
#   'environment',
#   'disaster, accident and emergency incident',
#   'human interest'],
#  ['sport',
#   'labour',
#   'environment',
#   'economy, business and finance',
#   'arts, culture, entertainment and media'],
#  ['sport',
#   'economy, business and finance',
#   'arts, culture, entertainment and media',
#   'environment',
#   'society'],
#  ['religion and belief',
#   'politics',
#   'society',
#   'disaster, accident and emergency incident',
#   'human interest'],
#  ['disaster, accident and emergency incident',
#   'human interest',
#   'conflict, war and peace',
#   'environment',
#   'society'],
#  ['crime, law and justice',
#   'disaster, accident and emergency incident',
#   'human interest',
#   'society',
#   'health'],
#  ['health',
#   'human interest',
#   'society',
#   'environment',
#   'science and technology'],
#  ['education',
#   'human interest',
#   'arts, culture, entertainment and media',
#   'environment',
#   'society'],
#  ['disaster, accident and emergency incident',
#   'crime, law and justice',
#   'human interest',
#   'society',
#   'health'],
#  ['society',
#   'politics',
#   'disaster, accident and emergency incident',
#   'health',
#   'economy, business and finance'],
#  ['health',
#   'society',
#   'human interest',
#   'economy, business and finance',
#   'lifestyle and leisure'],
#  ['crime, law and justice',
#   'society',
#   'human interest',
#   'conflict, war and peace',
#   'economy, business and finance'],
#  ['health',
#   'human interest',
#   'environment',
#   'disaster, accident and emergency incident',
#   'science and technology'],
#  ['health',
#   'science and technology',
#   'human interest',
#   'lifestyle and leisure',
#   'society'],
#  ['sport',
#   'arts, culture, entertainment and media',
#   'lifestyle and leisure',
#   'human interest',
#   'society'],
#  ['society',
#   'crime, law and justice',
#   'politics',
#   'conflict, war and peace',
#   'human interest'],
#  ['economy, business and finance',
#   'society',
#   'health',
#   'human interest',
#   'science and technology'],
#  ['religion and belief',
#   'society',
#   'politics',
#   'environment',
#   'human interest'],
#  ['disaster, accident and emergency incident',
#   'crime, law and justice',
#   'human interest',
#   'society',
#   'environment'],
#  ['politics', 'environment', 'society', 'human interest', 'education'],
#  ['disaster, accident and emergency incident',
#   'weather',
#   'society',
#   'environment',
#   'human interest'],
#  ['sport',
#   'human interest',
#   'health',
#   'arts, culture, entertainment and media',
#   'environment'],
#  ['politics',
#   'human interest',
#   'society',
#   'arts, culture, entertainment and media',
#   'economy, business and finance'],
#  ['weather',
#   'disaster, accident and emergency incident',
#   'society',
#   'environment',
#   'lifestyle and leisure'],
#  ['society',
#   'human interest',
#   'crime, law and justice',
#   'weather',
#   'politics'],
#  ['crime, law and justice',
#   'conflict, war and peace',
#   'human interest',
#   'society',
#   'environment'],
#  ['education',
#   'human interest',
#   'disaster, accident and emergency incident',
#   'society',
#   'crime, law and justice'],
#  ['sport',
#   'arts, culture, entertainment and media',
#   'economy, business and finance',
#   'human interest',
#   'society'],
#  ['politics',
#   'conflict, war and peace',
#   'society',
#   'disaster, accident and emergency incident',
#   'religion and belief'],
#  ['arts, culture, entertainment and media',
#   'economy, business and finance',
#   'society',
#   'human interest',
#   'environment'],
#  ['politics',
#   'society',
#   'human interest',
#   'religion and belief',
#   'lifestyle and leisure'],
#  ['economy, business and finance',
#   'sport',
#   'human interest',
#   'environment',
#   'conflict, war and peace'],
#  ['arts, culture, entertainment and media',
#   'disaster, accident and emergency incident',
#   'conflict, war and peace',
#   'society',
#   'politics']]

# %%
df2_pred5 = find_matching_category_for_each_list(df2_pred5 , y_test)

# %%
df2_pred5
# Out:
# ['science and technology',
#  'education',
#  'lifestyle and leisure',
#  'education',
#  'arts, culture, entertainment and media',
#  'human interest',
#  'labour',
#  'weather',
#  'society',
#  'conflict, war and peace',
#  'science and technology',
#  'sport',
#  'religion and belief',
#  'weather',
#  'society',
#  'religion and belief',
#  'lifestyle and leisure',
#  'health',
#  'politics',
#  'crime, law and justice',
#  'religion and belief',
#  'conflict, war and peace',
#  'religion and belief',
#  'religion and belief',
#  'environment',
#  'health',
#  'sport',
#  'society',
#  'politics',
#  'environment',
#  'crime, law and justice',
#  'crime, law and justice',
#  'society',
#  'society',
#  'society',
#  'society',
#  'sport',
#  'health',
#  'human interest',
#  'economy, business and finance',
#  'arts, culture, entertainment and media',
#  'conflict, war and peace',
#  'conflict, war and peace',
#  'sport',
#  'society',
#  'health',
#  'weather',
#  'labour',
#  'lifestyle and leisure',
#  'environment',
#  'economy, business and finance',
#  'conflict, war and peace',
#  'economy, business and finance',
#  'health',
#  'economy, business and finance',
#  'environment',
#  'science and technology',
#  'crime, law and justice',
#  'politics',
#  'disaster, accident and emergency incident',
#  'health',
#  'education',
#  'religion and belief',
#  'labour',
#  'human interest',
#  'health',
#  'science and technology',
#  'environment',
#  'sport',
#  'sport',
#  'religion and belief',
#  'human interest',
#  'disaster, accident and emergency incident',
#  'society',
#  'education',
#  'disaster, accident and emergency incident',
#  'politics',
#  'society',
#  'crime, law and justice',
#  'health',
#  'health',
#  'sport',
#  'conflict, war and peace',
#  'economy, business and finance',
#  'religion and belief',
#  'disaster, accident and emergency incident',
#  'education',
#  'disaster, accident and emergency incident',
#  'sport',
#  'politics',
#  'weather',
#  'politics',
#  'conflict, war and peace',
#  'education',
#  'sport',
#  'politics',
#  'arts, culture, entertainment and media',
#  'politics',
#  'sport',
#  'arts, culture, entertainment and media']

# %%
compute_classification_report(y_test , df2_pred5)
# Out:
#                                            precision    recall  f1-score   support
#
#    arts, culture, entertainment and media       0.50      0.67      0.57         3
#                   conflict, war and peace       1.00      1.00      1.00         7
#                    crime, law and justice       1.00      1.00      1.00         5
# disaster, accident and emergency incident       1.00      1.00      1.00         5
#             economy, business and finance       0.80      1.00      0.89         4
#                                 education       0.83      0.83      0.83         6
#                               environment       1.00      0.83      0.91         6
#                                    health       0.67      1.00      0.80         6
#                            human interest       0.75      0.60      0.67         5
#                                    labour       1.00      0.50      0.67         6
#                     lifestyle and leisure       0.67      0.67      0.67         3
#                                  politics       1.00      1.00      1.00         8
#                       religion and belief       0.88      1.00      0.93         7
#                    science and technology       1.00      0.57      0.73         7
#                                   society       0.90      0.90      0.90        10
#                                     sport       0.80      1.00      0.89         8
#                                   weather       1.00      1.00      1.00         4
#
#                                  accuracy                           0.87       100
#                                 macro avg       0.87      0.86      0.85       100
#                              weighted avg       0.89      0.87      0.87       100
# 0.87

# %%
# !pip install ktrain
# Out:
# Requirement already satisfied: ktrain in /usr/local/lib/python3.10/dist-packages (0.38.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from ktrain) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from ktrain) (3.7.1)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from ktrain) (1.5.3)
# Requirement already satisfied: fastprogress>=0.1.21 in /usr/local/lib/python3.10/dist-packages (from ktrain) (1.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ktrain) (2.31.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from ktrain) (1.3.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from ktrain) (23.2)
# Requirement already satisfied: langdetect in /usr/local/lib/python3.10/dist-packages (from ktrain) (1.0.9)
# Requirement already satisfied: jieba in /usr/local/lib/python3.10/dist-packages (from ktrain) (0.42.1)
# Requirement already satisfied: cchardet in /usr/local/lib/python3.10/dist-packages (from ktrain) (2.1.7)
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (from ktrain) (5.2.0)
# Requirement already satisfied: syntok>1.3.3 in /usr/local/lib/python3.10/dist-packages (from ktrain) (1.4.4)
# Requirement already satisfied: tika in /usr/local/lib/python3.10/dist-packages (from ktrain) (2.6.0)
# Requirement already satisfied: transformers>=4.17.0 in /usr/local/lib/python3.10/dist-packages (from ktrain) (4.34.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from ktrain) (0.1.99)
# Requirement already satisfied: keras-bert>=0.86.0 in /usr/local/lib/python3.10/dist-packages (from ktrain) (0.89.0)
# Requirement already satisfied: whoosh in /usr/local/lib/python3.10/dist-packages (from ktrain) (2.7.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-bert>=0.86.0->ktrain) (1.23.5)
# Requirement already satisfied: keras-transformer==0.40.0 in /usr/local/lib/python3.10/dist-packages (from keras-bert>=0.86.0->ktrain) (0.40.0)
# Requirement already satisfied: keras-pos-embd==0.13.0 in /usr/local/lib/python3.10/dist-packages (from keras-transformer==0.40.0->keras-bert>=0.86.0->ktrain) (0.13.0)
# Requirement already satisfied: keras-multi-head==0.29.0 in /usr/local/lib/python3.10/dist-packages (from keras-transformer==0.40.0->keras-bert>=0.86.0->ktrain) (0.29.0)
# Requirement already satisfied: keras-layer-normalization==0.16.0 in /usr/local/lib/python3.10/dist-packages (from keras-transformer==0.40.0->keras-bert>=0.86.0->ktrain) (0.16.0)
# Requirement already satisfied: keras-position-wise-feed-forward==0.8.0 in /usr/local/lib/python3.10/dist-packages (from keras-transformer==0.40.0->keras-bert>=0.86.0->ktrain) (0.8.0)
# Requirement already satisfied: keras-embed-sim==0.10.0 in /usr/local/lib/python3.10/dist-packages (from keras-transformer==0.40.0->keras-bert>=0.86.0->ktrain) (0.10.0)
# Requirement already satisfied: keras-self-attention==0.51.0 in /usr/local/lib/python3.10/dist-packages (from keras-multi-head==0.29.0->keras-transformer==0.40.0->keras-bert>=0.86.0->ktrain) (0.51.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->ktrain) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->ktrain) (2023.3.post1)
# Requirement already satisfied: regex>2016 in /usr/local/lib/python3.10/dist-packages (from syntok>1.3.3->ktrain) (2023.6.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.17.0->ktrain) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.17.0->ktrain) (0.17.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.17.0->ktrain) (6.0.1)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.17.0->ktrain) (0.14.1)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.17.0->ktrain) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.17.0->ktrain) (4.66.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from langdetect->ktrain) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->ktrain) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ktrain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ktrain) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ktrain) (2023.7.22)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->ktrain) (1.11.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->ktrain) (3.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tika->ktrain) (67.7.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers>=4.17.0->ktrain) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers>=4.17.0->ktrain) (4.5.0)

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID";
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from ktrain.text.zsl import ZeroShotClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Fing the first category from the prpbability

# %%
def find_max_categories_for_lists(lists_of_category_scores):
    max_categories = []
    for category_scores in lists_of_category_scores:
        max_category = max(category_scores, key=lambda x: x[1])[0]
        max_categories.append(max_category)
    return max_categories

# %%
def find_top_categories_for_lists(lists_of_category_scores, num_categories):
    top_categories = []
    for category_scores in lists_of_category_scores:
        # Sort the categories based on their values in descending order
        sorted_categories = sorted(category_scores, key=lambda x: x[1], reverse=True)
        # Select the top 'num_categories' categories
        top_categories_list = [category[0] for category in sorted_categories[:num_categories]]
        top_categories.append(top_categories_list)
    return top_categories

# %% [markdown]
# # Find the maximum first 2 categories fro mthe probability

# %%
def find_max_2_categories_for_lists(lists_of_category_scores):
    max_categories = []
    for category_scores in lists_of_category_scores:
        # Sort the categories based on their values in descending order
        sorted_categories = sorted(category_scores, key=lambda x: x[1], reverse=True)
        # Select the top two categories
        top_categories = [category[0] for category in sorted_categories[:2]]
        max_categories.append(top_categories)
    return max_categories

# %% [markdown]
# ## check for the best category from the first 2 categories depending on the label of this data
# if any of the 2 values are equal to the true label then return it
#
#
# if none of them are equal to the true label then return the first value with the highest probability

# %%
def return_best_category_from_2_categories(list1, list2):
  result = []
  for item1, item2 in zip(list1, list2):
      found = False
      for value in item2:
          if value in item1:
              result.append(value)
              found = True
              break
      if not found:
          result.append(item2[0])
  return result

# %%
def find_matching_category_or_first(list1, list2):
    for category in list1:
        if category in list2:
            return category
    return list1[0]
def find_matching_category_for_each_list(list1, list2):
    results = []
    for sublist, category in zip(list1, list2):
        result = find_matching_category_or_first(sublist, [category])
        results.append(result)
    return results

# %% [markdown]
# # Find the maximum first 3 categories fro mthe probability

# %%
def find_max_3_categories_for_lists(lists_of_category_scores):
    max_categories = []
    for category_scores in lists_of_category_scores:
        # Sort the categories based on their values in descending order
        sorted_categories = sorted(category_scores, key=lambda x: x[1], reverse=True)
        # Select the top three categories
        top_categories = [category[0] for category in sorted_categories[:3]]
        max_categories.append(top_categories)
    return max_categories

# %%
def return_best_category_from_3_categories(list1, list2):
    result = []
    for item1, item2 in zip(list1, list2):
        found = False
        for value in item2:
            if value in item1:
                result.append(value)
                found = True
                break
        if not found:
            result.append(item1[0])
    return result

# %%
def compute_classification_report(y_true, y_pred):

    report = classification_report(y_true, y_pred)
    print(report)
    accuracy = accuracy_score(y_true, y_pred)
    return accuracy

# %%
def find_max_value(category_scores):
    max_value = max(category_scores, key=lambda x: x[1])[1]
    return max_value

# %%
df = pd.read_csv("https://github.com/AnasElbattra/News-Understanding-NLP/raw/main/TOPICS/DATA/MN-DS-news-classification.csv")
df = df.rename(columns={'category_level_1': 'category_1', 'category_level_2': 'category_2'})
df
# Out:
#        data_id                                                 id        date  \
# 0         1809  abcnews--2019-10-31--Virginia mom charged with...  2019-10-31
# 1         1980  abcnews--2019-11-07--2 escaped murder suspects...  2019-11-07
# 2         1995  abcnews--2019-11-07--Family turns in escaped b...  2019-11-07
# 3         2740  abcnews--2019-12-02--Mother charged with murde...  2019-12-02
# 4         7038  ageofautism--2019-04-12--Physician Father and ...  2019-04-12
# ...        ...                                                ...         ...
# 10912   907640  therussophileorg--2019-12-15--Iran to build ov...  2019-12-15
# 10913   892720  therussophileorg--2019-10-12--Ukraine has no m...  2019-10-12
# 10914   870499  therussophileorg--2019-07-06--Irans contributi...  2019-07-06
# 10915   887334  therussophileorg--2019-09-25--Iraqi president ...  2019-09-25
# 10916   885988  therussophileorg--2019-09-20--Russia expects t...  2019-09-20
#
#                  source                                              title  \
# 0               abcnews  Virginia mom charged with murder in 2-year-old...
# 1               abcnews  2 escaped murder suspects arrested at US-Mexic...
# 2               abcnews  Family turns in escaped boy, 13, suspected in ...
# 3               abcnews  Mother charged with murder in deaths of 2 youn...
# 4           ageofautism  Physician, Father and Caretaker of 29 Year Old...
# ...                 ...                                                ...
# 10912  therussophileorg  Iran to build over 30,000 housing units in Syr...
# 10913  therussophileorg  Ukraine has no money for reconstruction of Don...
# 10914  therussophileorg  Iran’s contribution is needed to rebuild Iraq ...
# 10915  therussophileorg  Iraqi president demands international help for...
# 10916  therussophileorg  Russia expects to cooperate with China on Syri...
#
#                                                  content            author  \
# 0      The Virginia woman whose 2-year-old son was fo...               NaN
# 1      Authorities are trying to determine if anyone ...               NaN
# 2      A 13-year-old suspect in a double homicide who...               NaN
# 3      The mother of two young children found hanging...               NaN
# 4      "One family member said Derek “can be violent ...     Age of Autism
# ...                                                  ...               ...
# 10912  This post was originally published on this sit...         News Desk
# 10913  This post was originally published on this sit...  Michael Sullivan
# 10914  This\n\n[post](http://www.presstv.ir/Detail/20...  Michael Sullivan
# 10915  This\n\n[post](http://www.presstv.ir/Detail/20...  Michael Sullivan
# 10916  This\n\n[post](https://tass.com/politics/10791...  Michael Sullivan
#
#                                                      url  \
# 0      https://abcnews.go.com/US/wireStory/virginia-m...
# 1      https://abcnews.go.com/US/wireStory/escaped-mu...
# 2      https://abcnews.go.com/US/wireStory/family-tur...
# 3      https://abcnews.go.com/US/wireStory/mother-cha...
# 4      http://feedproxy.google.com/~r/ageofautism/~3/...
# ...                                                  ...
# 10912  https://www.therussophile.org/iran-to-build-ov...
# 10913  https://www.therussophile.org/ukraine-has-no-m...
# 10914  https://www.therussophile.org/irans-contributi...
# 10915  https://www.therussophile.org/iraqi-president-...
# 10916  https://www.therussophile.org/russia-expects-t...
#
#                              published  published_utc  collection_utc  \
# 0      Thu, 31 Oct 2019 16:49:56 -0400     1572554996      1572559512
# 1      Thu, 07 Nov 2019 00:13:12 -0500     1573103592      1573131986
# 2      Thu, 07 Nov 2019 07:39:54 -0500     1573130394      1573131982
# 3      Mon, 02 Dec 2019 11:30:59 -0500     1575304259      1575308811
# 4            2019-04-12 09:00:00+00:00     1555074000      1567543083
# ...                                ...            ...             ...
# 10912  Sun, 15 Dec 2019 10:42:50 +0000     1576424570      1576413702
# 10913  Sat, 12 Oct 2019 20:56:01 +0000     1570928161      1570922006
# 10914        2019-07-06 17:51:38+00:00     1562449898      1567536625
# 10915        2019-09-25 16:58:01+00:00     1569445081      1570222223
# 10916        2019-09-20 13:56:47+00:00     1569002207      1570222711
#
#                     category_1               category_2
# 0       crime, law and justice                    crime
# 1       crime, law and justice                    crime
# 2       crime, law and justice                    crime
# 3       crime, law and justice                    crime
# 4       crime, law and justice                    crime
# ...                        ...                      ...
# 10912  conflict, war and peace  post-war reconstruction
# 10913  conflict, war and peace  post-war reconstruction
# 10914  conflict, war and peace  post-war reconstruction
# 10915  conflict, war and peace  post-war reconstruction
# 10916  conflict, war and peace  post-war reconstruction
#
# [10917 rows x 13 columns]

# %%
df.content[0]
# Out:
# "The Virginia woman whose 2-year-old son was found in a trash incinerator has been charged with murder in his death.\n\nHampton Commonwealth's Attorney Anton Bell told a news conference on Thursday that a warrant had been issued for 34-year-old Julia Leanna Tomlin, who also will be charged with unlawfully disposing of Noah Tomlin's body.\n\nBell said skull fractures found on the toddler's body indicates a level of force so severe it was as if the child had fallen several stories from a building.\n\nJulia Tomlin reported her son missing in June, and searchers sifted through a landfill and steam plant over 10 days before the body was found on July 3. Tomlin is already jailed and charged with three counts of felony child neglect prior to reporting Noah missing."

# %%
X = df.content
Y = df.category_1

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y , shuffle=True, test_size = 100, random_state = 42 , stratify=Y)

# %%
y_test[:7]
# Out:
# 5774     science and technology
# 10679                 education
# 2738             human interest
# 7636                  education
# 7130                  education
# 328              human interest
# 8437                     labour
# Name: category_1, dtype: object

# %%
zsl = ZeroShotClassifier()
labels=['arts, culture, entertainment and media',
       'conflict, war and peace', 'crime, law and justice',
       'disaster, accident and emergency incident',
       'economy, business and finance', 'education', 'environment',
       'health', 'human interest', 'labour', 'lifestyle and leisure',
       'politics', 'religion and belief', 'science and technology',
       'society', 'sport', 'weather']

# %%
doc = """The Virginia woman whose 2-year-old son was found in a trash incinerator has been charged with murder in his death.

Hampton Commonwealth's Attorney Anton Bell told a news conference on Thursday that a warrant had been issued for 34-year-old Julia Leanna Tomlin, who also will be charged with unlawfully disposing of Noah Tomlin's body.

Bell said skull fractures found on the toddler's body indicates a level of force so severe it was as if the child had fallen several stories from a building.

Julia Tomlin reported her son missing in June, and searchers sifted through a landfill and steam plant over 10 days before the body was found on July 3. Tomlin is already jailed and charged with three counts of felony child neglect prior to reporting Noah missing."""
# trn = train["Excerpt"].iloc[:100].values
# y_trn = train["Category"].iloc[:100].values
# tst = test["Excerpt"].values
# y_tst = test["Category"].values

# %%
# %%time
doc_prb = zsl.predict(X_test.values, labels=labels, include_labels=True , batch_size = 16)
# Out:
# CPU times: user 3min 15s, sys: 345 ms, total: 3min 16s
# Wall time: 3min 15s

# %%
doc_prb[0]
# Out:
# [('arts, culture, entertainment and media', 0.09670595079660416),
#  ('conflict, war and peace', 0.010952865704894066),
#  ('crime, law and justice', 0.019518446177244186),
#  ('disaster, accident and emergency incident', 0.034119393676519394),
#  ('economy, business and finance', 0.08047517389059067),
#  ('education', 0.22910906374454498),
#  ('environment', 0.07062825560569763),
#  ('health', 0.0264512300491333),
#  ('human interest', 0.1691930741071701),
#  ('labour', 0.10658044368028641),
#  ('lifestyle and leisure', 0.12848258018493652),
#  ('politics', 0.02546461671590805),
#  ('religion and belief', 0.013670114800333977),
#  ('science and technology', 0.6388155221939087),
#  ('society', 0.601854145526886),
#  ('sport', 0.010769632644951344),
#  ('weather', 0.00610692473128438)]

# %% [markdown]
# # **1**

# %%
df2_pred1 = find_top_categories_for_lists(doc_prb , 1)
# y_trn_pred = find_max_categories_for_lists(y_trn_prb)
# y_tst_pred = find_max_categories_for_lists(y_tst_prb)

# %%
df2_pred1
# Out:
# [['science and technology'],
#  ['education'],
#  ['lifestyle and leisure'],
#  ['education'],
#  ['arts, culture, entertainment and media'],
#  ['human interest'],
#  ['economy, business and finance'],
#  ['disaster, accident and emergency incident'],
#  ['politics'],
#  ['conflict, war and peace'],
#  ['society'],
#  ['sport'],
#  ['conflict, war and peace'],
#  ['weather'],
#  ['economy, business and finance'],
#  ['religion and belief'],
#  ['health'],
#  ['health'],
#  ['politics'],
#  ['human interest'],
#  ['religion and belief'],
#  ['politics'],
#  ['crime, law and justice'],
#  ['religion and belief'],
#  ['politics'],
#  ['human interest'],
#  ['sport'],
#  ['politics'],
#  ['human interest'],
#  ['science and technology'],
#  ['crime, law and justice'],
#  ['environment'],
#  ['society'],
#  ['human interest'],
#  ['society'],
#  ['arts, culture, entertainment and media'],
#  ['sport'],
#  ['health'],
#  ['human interest'],
#  ['economy, business and finance'],
#  ['economy, business and finance'],
#  ['conflict, war and peace'],
#  ['human interest'],
#  ['sport'],
#  ['crime, law and justice'],
#  ['human interest'],
#  ['weather'],
#  ['economy, business and finance'],
#  ['lifestyle and leisure'],
#  ['environment'],
#  ['economy, business and finance'],
#  ['conflict, war and peace'],
#  ['crime, law and justice'],
#  ['health'],
#  ['economy, business and finance'],
#  ['human interest'],
#  ['science and technology'],
#  ['health'],
#  ['politics'],
#  ['disaster, accident and emergency incident'],
#  ['politics'],
#  ['education'],
#  ['religion and belief'],
#  ['labour'],
#  ['human interest'],
#  ['health'],
#  ['science and technology'],
#  ['health'],
#  ['sport'],
#  ['sport'],
#  ['religion and belief'],
#  ['disaster, accident and emergency incident'],
#  ['crime, law and justice'],
#  ['health'],
#  ['education'],
#  ['disaster, accident and emergency incident'],
#  ['society'],
#  ['health'],
#  ['crime, law and justice'],
#  ['health'],
#  ['health'],
#  ['sport'],
#  ['society'],
#  ['economy, business and finance'],
#  ['religion and belief'],
#  ['disaster, accident and emergency incident'],
#  ['politics'],
#  ['disaster, accident and emergency incident'],
#  ['sport'],
#  ['politics'],
#  ['weather'],
#  ['society'],
#  ['crime, law and justice'],
#  ['education'],
#  ['sport'],
#  ['politics'],
#  ['arts, culture, entertainment and media'],
#  ['politics'],
#  ['economy, business and finance'],
#  ['arts, culture, entertainment and media']]

# %%
compute_classification_report(y_test , df2_pred1)
# Out:
#                                            precision    recall  f1-score   support
#
#    arts, culture, entertainment and media       0.25      0.33      0.29         3
#                   conflict, war and peace       0.75      0.43      0.55         7
#                    crime, law and justice       0.29      0.40      0.33         5
# disaster, accident and emergency incident       0.67      0.80      0.73         5
#             economy, business and finance       0.33      0.75      0.46         4
#                                 education       0.80      0.67      0.73         6
#                               environment       0.50      0.17      0.25         6
#                                    health       0.27      0.50      0.35         6
#                            human interest       0.20      0.40      0.27         5
#                                    labour       1.00      0.17      0.29         6
#                     lifestyle and leisure       0.50      0.33      0.40         3
#                                  politics       0.45      0.62      0.53         8
#                       religion and belief       0.83      0.71      0.77         7
#                    science and technology       0.75      0.43      0.55         7
#                                   society       0.17      0.10      0.12        10
#                                     sport       0.78      0.88      0.82         8
#                                   weather       1.00      0.75      0.86         4
#
#                                  accuracy                           0.49       100
#                                 macro avg       0.56      0.50      0.49       100
#                              weighted avg       0.57      0.49      0.49       100
# 0.49

# %%
# compute_classification_report(y_trn , y_trn_pred)

# %%
# compute_classification_report(y_tst , y_tst_pred)

# %% [markdown]
# # **2**

# %% [markdown]
# ## After getting the 2 maximum probability categories i check if **the first or the second** category is the same as true label and get the classification report

# %%
df2_pred2 = find_top_categories_for_lists(doc_prb , 2)
# y_trn_pred = find_max_2_categories_for_lists(y_trn_prb)
# y_tst_pred = find_max_2_categories_for_lists(y_tst_prb)

# %%
df2_pred2
# Out:
# [['science and technology', 'society'],
#  ['education', 'religion and belief'],
#  ['lifestyle and leisure', 'arts, culture, entertainment and media'],
#  ['education', 'human interest'],
#  ['arts, culture, entertainment and media', 'sport'],
#  ['human interest', 'lifestyle and leisure'],
#  ['economy, business and finance', 'society'],
#  ['disaster, accident and emergency incident', 'weather'],
#  ['politics', 'society'],
#  ['conflict, war and peace', 'politics'],
#  ['society', 'environment'],
#  ['sport', 'human interest'],
#  ['conflict, war and peace', 'religion and belief'],
#  ['weather', 'society'],
#  ['economy, business and finance', 'society'],
#  ['religion and belief', 'arts, culture, entertainment and media'],
#  ['health', 'sport'],
#  ['health', 'human interest'],
#  ['politics', 'society'],
#  ['human interest', 'crime, law and justice'],
#  ['religion and belief', 'conflict, war and peace'],
#  ['politics', 'society'],
#  ['crime, law and justice', 'religion and belief'],
#  ['religion and belief', 'human interest'],
#  ['politics', 'environment'],
#  ['human interest', 'health'],
#  ['sport', 'human interest'],
#  ['politics', 'society'],
#  ['human interest', 'economy, business and finance'],
#  ['science and technology', 'human interest'],
#  ['crime, law and justice', 'society'],
#  ['environment', 'crime, law and justice'],
#  ['society', 'arts, culture, entertainment and media'],
#  ['human interest', 'arts, culture, entertainment and media'],
#  ['society', 'crime, law and justice'],
#  ['arts, culture, entertainment and media', 'human interest'],
#  ['sport', 'human interest'],
#  ['health', 'science and technology'],
#  ['human interest', 'science and technology'],
#  ['economy, business and finance', 'science and technology'],
#  ['economy, business and finance', 'society'],
#  ['conflict, war and peace', 'politics'],
#  ['human interest', 'conflict, war and peace'],
#  ['sport', 'arts, culture, entertainment and media'],
#  ['crime, law and justice', 'society'],
#  ['human interest', 'health'],
#  ['weather', 'disaster, accident and emergency incident'],
#  ['economy, business and finance', 'labour'],
#  ['lifestyle and leisure', 'arts, culture, entertainment and media'],
#  ['environment', 'conflict, war and peace'],
#  ['economy, business and finance', 'science and technology'],
#  ['conflict, war and peace', 'disaster, accident and emergency incident'],
#  ['crime, law and justice', 'economy, business and finance'],
#  ['health', 'environment'],
#  ['economy, business and finance', 'society'],
#  ['human interest', 'society'],
#  ['science and technology', 'labour'],
#  ['health', 'education'],
#  ['politics', 'society'],
#  ['disaster, accident and emergency incident', 'society'],
#  ['politics', 'health'],
#  ['education', 'human interest'],
#  ['religion and belief', 'politics'],
#  ['labour', 'politics'],
#  ['human interest', 'health'],
#  ['health', 'politics'],
#  ['science and technology', 'arts, culture, entertainment and media'],
#  ['health', 'science and technology'],
#  ['sport', 'labour'],
#  ['sport', 'economy, business and finance'],
#  ['religion and belief', 'politics'],
#  ['disaster, accident and emergency incident', 'human interest'],
#  ['crime, law and justice', 'disaster, accident and emergency incident'],
#  ['health', 'human interest'],
#  ['education', 'human interest'],
#  ['disaster, accident and emergency incident', 'crime, law and justice'],
#  ['society', 'politics'],
#  ['health', 'society'],
#  ['crime, law and justice', 'society'],
#  ['health', 'human interest'],
#  ['health', 'science and technology'],
#  ['sport', 'arts, culture, entertainment and media'],
#  ['society', 'crime, law and justice'],
#  ['economy, business and finance', 'society'],
#  ['religion and belief', 'society'],
#  ['disaster, accident and emergency incident', 'crime, law and justice'],
#  ['politics', 'environment'],
#  ['disaster, accident and emergency incident', 'weather'],
#  ['sport', 'human interest'],
#  ['politics', 'human interest'],
#  ['weather', 'disaster, accident and emergency incident'],
#  ['society', 'human interest'],
#  ['crime, law and justice', 'conflict, war and peace'],
#  ['education', 'human interest'],
#  ['sport', 'arts, culture, entertainment and media'],
#  ['politics', 'conflict, war and peace'],
#  ['arts, culture, entertainment and media', 'economy, business and finance'],
#  ['politics', 'society'],
#  ['economy, business and finance', 'sport'],
#  ['arts, culture, entertainment and media',
#   'disaster, accident and emergency incident']]

# %%
df2_pred2 = find_matching_category_for_each_list(df2_pred2 , y_test)
# y_trn_pred = return_best_category_from_2_categories(y_trn , y_trn_pred)
# y_tst_pred = return_best_category_from_2_categories(y_tst , y_tst_pred)

# %%
df2_pred2
# Out:
# ['science and technology',
#  'education',
#  'lifestyle and leisure',
#  'education',
#  'arts, culture, entertainment and media',
#  'human interest',
#  'economy, business and finance',
#  'weather',
#  'society',
#  'conflict, war and peace',
#  'society',
#  'sport',
#  'religion and belief',
#  'weather',
#  'society',
#  'religion and belief',
#  'health',
#  'health',
#  'politics',
#  'crime, law and justice',
#  'religion and belief',
#  'politics',
#  'religion and belief',
#  'religion and belief',
#  'environment',
#  'health',
#  'sport',
#  'society',
#  'human interest',
#  'science and technology',
#  'crime, law and justice',
#  'crime, law and justice',
#  'society',
#  'human interest',
#  'society',
#  'arts, culture, entertainment and media',
#  'sport',
#  'health',
#  'human interest',
#  'economy, business and finance',
#  'economy, business and finance',
#  'conflict, war and peace',
#  'conflict, war and peace',
#  'sport',
#  'society',
#  'health',
#  'weather',
#  'labour',
#  'lifestyle and leisure',
#  'environment',
#  'economy, business and finance',
#  'conflict, war and peace',
#  'economy, business and finance',
#  'health',
#  'economy, business and finance',
#  'human interest',
#  'science and technology',
#  'health',
#  'politics',
#  'disaster, accident and emergency incident',
#  'health',
#  'education',
#  'religion and belief',
#  'labour',
#  'human interest',
#  'health',
#  'science and technology',
#  'health',
#  'sport',
#  'sport',
#  'religion and belief',
#  'human interest',
#  'disaster, accident and emergency incident',
#  'health',
#  'education',
#  'disaster, accident and emergency incident',
#  'politics',
#  'society',
#  'crime, law and justice',
#  'health',
#  'health',
#  'sport',
#  'society',
#  'economy, business and finance',
#  'religion and belief',
#  'disaster, accident and emergency incident',
#  'politics',
#  'disaster, accident and emergency incident',
#  'sport',
#  'politics',
#  'weather',
#  'society',
#  'conflict, war and peace',
#  'education',
#  'sport',
#  'politics',
#  'arts, culture, entertainment and media',
#  'politics',
#  'sport',
#  'arts, culture, entertainment and media']

# %%
compute_classification_report(y_test , df2_pred2)
# Out:
#                                            precision    recall  f1-score   support
#
#    arts, culture, entertainment and media       0.25      0.33      0.29         3
#                   conflict, war and peace       1.00      0.71      0.83         7
#                    crime, law and justice       1.00      0.80      0.89         5
# disaster, accident and emergency incident       1.00      1.00      1.00         5
#             economy, business and finance       0.57      1.00      0.73         4
#                                 education       0.80      0.67      0.73         6
#                               environment       1.00      0.33      0.50         6
#                                    health       0.46      1.00      0.63         6
#                            human interest       0.43      0.60      0.50         5
#                                    labour       1.00      0.33      0.50         6
#                     lifestyle and leisure       0.50      0.33      0.40         3
#                                  politics       0.75      0.75      0.75         8
#                       religion and belief       0.88      1.00      0.93         7
#                    science and technology       0.75      0.43      0.55         7
#                                   society       0.60      0.60      0.60        10
#                                     sport       0.80      1.00      0.89         8
#                                   weather       1.00      1.00      1.00         4
#
#                                  accuracy                           0.71       100
#                                 macro avg       0.75      0.70      0.69       100
#                              weighted avg       0.77      0.71      0.70       100
# 0.71

# %%
# compute_classification_report(y_trn , y_trn_pred)

# %%
# compute_classification_report(y_tst , y_tst_pred)

# %% [markdown]
# # **3**

# %%
df2_pred3 = find_top_categories_for_lists(doc_prb , 3)

# %%
df2_pred3
# Out:
# [['science and technology', 'society', 'education'],
#  ['education', 'religion and belief', 'society'],
#  ['lifestyle and leisure', 'arts, culture, entertainment and media', 'health'],
#  ['education', 'human interest', 'science and technology'],
#  ['arts, culture, entertainment and media', 'sport', 'society'],
#  ['human interest',
#   'lifestyle and leisure',
#   'arts, culture, entertainment and media'],
#  ['economy, business and finance', 'society', 'politics'],
#  ['disaster, accident and emergency incident', 'weather', 'society'],
#  ['politics', 'society', 'religion and belief'],
#  ['conflict, war and peace', 'politics', 'society'],
#  ['society', 'environment', 'science and technology'],
#  ['sport', 'human interest', 'economy, business and finance'],
#  ['conflict, war and peace',
#   'religion and belief',
#   'disaster, accident and emergency incident'],
#  ['weather', 'society', 'human interest'],
#  ['economy, business and finance', 'society', 'crime, law and justice'],
#  ['religion and belief',
#   'arts, culture, entertainment and media',
#   'human interest'],
#  ['health', 'sport', 'lifestyle and leisure'],
#  ['health', 'human interest', 'society'],
#  ['politics', 'society', 'conflict, war and peace'],
#  ['human interest',
#   'crime, law and justice',
#   'disaster, accident and emergency incident'],
#  ['religion and belief', 'conflict, war and peace', 'education'],
#  ['politics', 'society', 'conflict, war and peace'],
#  ['crime, law and justice', 'religion and belief', 'society'],
#  ['religion and belief', 'human interest', 'conflict, war and peace'],
#  ['politics', 'environment', 'society'],
#  ['human interest', 'health', 'science and technology'],
#  ['sport', 'human interest', 'arts, culture, entertainment and media'],
#  ['politics', 'society', 'economy, business and finance'],
#  ['human interest', 'economy, business and finance', 'society'],
#  ['science and technology', 'human interest', 'environment'],
#  ['crime, law and justice', 'society', 'human interest'],
#  ['environment', 'crime, law and justice', 'science and technology'],
#  ['society',
#   'arts, culture, entertainment and media',
#   'economy, business and finance'],
#  ['human interest',
#   'arts, culture, entertainment and media',
#   'lifestyle and leisure'],
#  ['society', 'crime, law and justice', 'lifestyle and leisure'],
#  ['arts, culture, entertainment and media', 'human interest', 'society'],
#  ['sport', 'human interest', 'society'],
#  ['health',
#   'science and technology',
#   'disaster, accident and emergency incident'],
#  ['human interest', 'science and technology', 'society'],
#  ['economy, business and finance', 'science and technology', 'society'],
#  ['economy, business and finance', 'society', 'lifestyle and leisure'],
#  ['conflict, war and peace', 'politics', 'society'],
#  ['human interest', 'conflict, war and peace', 'society'],
#  ['sport', 'arts, culture, entertainment and media', 'science and technology'],
#  ['crime, law and justice', 'society', 'human interest'],
#  ['human interest', 'health', 'education'],
#  ['weather', 'disaster, accident and emergency incident', 'human interest'],
#  ['economy, business and finance', 'labour', 'society'],
#  ['lifestyle and leisure',
#   'arts, culture, entertainment and media',
#   'environment'],
#  ['environment', 'conflict, war and peace', 'politics'],
#  ['economy, business and finance',
#   'science and technology',
#   'disaster, accident and emergency incident'],
#  ['conflict, war and peace',
#   'disaster, accident and emergency incident',
#   'politics'],
#  ['crime, law and justice', 'economy, business and finance', 'society'],
#  ['health', 'environment', 'society'],
#  ['economy, business and finance', 'society', 'conflict, war and peace'],
#  ['human interest', 'society', 'lifestyle and leisure'],
#  ['science and technology', 'labour', 'human interest'],
#  ['health', 'education', 'society'],
#  ['politics', 'society', 'environment'],
#  ['disaster, accident and emergency incident', 'society', 'environment'],
#  ['politics', 'health', 'human interest'],
#  ['education', 'human interest', 'labour'],
#  ['religion and belief', 'politics', 'conflict, war and peace'],
#  ['labour', 'politics', 'society'],
#  ['human interest', 'health', 'arts, culture, entertainment and media'],
#  ['health', 'politics', 'society'],
#  ['science and technology',
#   'arts, culture, entertainment and media',
#   'disaster, accident and emergency incident'],
#  ['health', 'science and technology', 'environment'],
#  ['sport', 'labour', 'environment'],
#  ['sport',
#   'economy, business and finance',
#   'arts, culture, entertainment and media'],
#  ['religion and belief', 'politics', 'society'],
#  ['disaster, accident and emergency incident',
#   'human interest',
#   'conflict, war and peace'],
#  ['crime, law and justice',
#   'disaster, accident and emergency incident',
#   'human interest'],
#  ['health', 'human interest', 'society'],
#  ['education', 'human interest', 'arts, culture, entertainment and media'],
#  ['disaster, accident and emergency incident',
#   'crime, law and justice',
#   'human interest'],
#  ['society', 'politics', 'disaster, accident and emergency incident'],
#  ['health', 'society', 'human interest'],
#  ['crime, law and justice', 'society', 'human interest'],
#  ['health', 'human interest', 'environment'],
#  ['health', 'science and technology', 'human interest'],
#  ['sport', 'arts, culture, entertainment and media', 'lifestyle and leisure'],
#  ['society', 'crime, law and justice', 'politics'],
#  ['economy, business and finance', 'society', 'health'],
#  ['religion and belief', 'society', 'politics'],
#  ['disaster, accident and emergency incident',
#   'crime, law and justice',
#   'human interest'],
#  ['politics', 'environment', 'society'],
#  ['disaster, accident and emergency incident', 'weather', 'society'],
#  ['sport', 'human interest', 'health'],
#  ['politics', 'human interest', 'society'],
#  ['weather', 'disaster, accident and emergency incident', 'society'],
#  ['society', 'human interest', 'crime, law and justice'],
#  ['crime, law and justice', 'conflict, war and peace', 'human interest'],
#  ['education', 'human interest', 'disaster, accident and emergency incident'],
#  ['sport',
#   'arts, culture, entertainment and media',
#   'economy, business and finance'],
#  ['politics', 'conflict, war and peace', 'society'],
#  ['arts, culture, entertainment and media',
#   'economy, business and finance',
#   'society'],
#  ['politics', 'society', 'human interest'],
#  ['economy, business and finance', 'sport', 'human interest'],
#  ['arts, culture, entertainment and media',
#   'disaster, accident and emergency incident',
#   'conflict, war and peace']]

# %%
df2_pred3 = find_matching_category_for_each_list(df2_pred3 , y_test)

# %%
df2_pred3
# Out:
# ['science and technology',
#  'education',
#  'lifestyle and leisure',
#  'education',
#  'arts, culture, entertainment and media',
#  'human interest',
#  'economy, business and finance',
#  'weather',
#  'society',
#  'conflict, war and peace',
#  'science and technology',
#  'sport',
#  'religion and belief',
#  'weather',
#  'society',
#  'religion and belief',
#  'lifestyle and leisure',
#  'health',
#  'politics',
#  'crime, law and justice',
#  'religion and belief',
#  'conflict, war and peace',
#  'religion and belief',
#  'religion and belief',
#  'environment',
#  'health',
#  'sport',
#  'society',
#  'human interest',
#  'environment',
#  'crime, law and justice',
#  'crime, law and justice',
#  'society',
#  'human interest',
#  'society',
#  'society',
#  'sport',
#  'health',
#  'human interest',
#  'economy, business and finance',
#  'economy, business and finance',
#  'conflict, war and peace',
#  'conflict, war and peace',
#  'sport',
#  'society',
#  'health',
#  'weather',
#  'labour',
#  'lifestyle and leisure',
#  'environment',
#  'economy, business and finance',
#  'conflict, war and peace',
#  'economy, business and finance',
#  'health',
#  'economy, business and finance',
#  'human interest',
#  'science and technology',
#  'health',
#  'politics',
#  'disaster, accident and emergency incident',
#  'health',
#  'education',
#  'religion and belief',
#  'labour',
#  'human interest',
#  'health',
#  'science and technology',
#  'environment',
#  'sport',
#  'sport',
#  'religion and belief',
#  'human interest',
#  'disaster, accident and emergency incident',
#  'society',
#  'education',
#  'disaster, accident and emergency incident',
#  'politics',
#  'society',
#  'crime, law and justice',
#  'health',
#  'health',
#  'sport',
#  'society',
#  'economy, business and finance',
#  'religion and belief',
#  'disaster, accident and emergency incident',
#  'politics',
#  'disaster, accident and emergency incident',
#  'sport',
#  'politics',
#  'weather',
#  'society',
#  'conflict, war and peace',
#  'education',
#  'sport',
#  'politics',
#  'arts, culture, entertainment and media',
#  'politics',
#  'sport',
#  'arts, culture, entertainment and media']

# %%
compute_classification_report(y_test , df2_pred3)
# Out:
#                                            precision    recall  f1-score   support
#
#    arts, culture, entertainment and media       0.33      0.33      0.33         3
#                   conflict, war and peace       1.00      0.86      0.92         7
#                    crime, law and justice       1.00      0.80      0.89         5
# disaster, accident and emergency incident       1.00      1.00      1.00         5
#             economy, business and finance       0.57      1.00      0.73         4
#                                 education       0.80      0.67      0.73         6
#                               environment       1.00      0.67      0.80         6
#                                    health       0.60      1.00      0.75         6
#                            human interest       0.43      0.60      0.50         5
#                                    labour       1.00      0.33      0.50         6
#                     lifestyle and leisure       0.67      0.67      0.67         3
#                                  politics       0.86      0.75      0.80         8
#                       religion and belief       0.88      1.00      0.93         7
#                    science and technology       1.00      0.57      0.73         7
#                                   society       0.73      0.80      0.76        10
#                                     sport       0.80      1.00      0.89         8
#                                   weather       1.00      1.00      1.00         4
#
#                                  accuracy                           0.78       100
#                                 macro avg       0.80      0.77      0.76       100
#                              weighted avg       0.82      0.78      0.78       100
# 0.78

# %% [markdown]
# # **4**

# %%
df2_pred4 = find_top_categories_for_lists(doc_prb , 4)

# %%
df2_pred4
# Out:
# [['science and technology', 'society', 'education', 'human interest'],
#  ['education', 'religion and belief', 'society', 'human interest'],
#  ['lifestyle and leisure',
#   'arts, culture, entertainment and media',
#   'health',
#   'environment'],
#  ['education', 'human interest', 'science and technology', 'health'],
#  ['arts, culture, entertainment and media',
#   'sport',
#   'society',
#   'lifestyle and leisure'],
#  ['human interest',
#   'lifestyle and leisure',
#   'arts, culture, entertainment and media',
#   'health'],
#  ['economy, business and finance', 'society', 'politics', 'human interest'],
#  ['disaster, accident and emergency incident',
#   'weather',
#   'society',
#   'human interest'],
#  ['politics', 'society', 'religion and belief', 'human interest'],
#  ['conflict, war and peace',
#   'politics',
#   'society',
#   'disaster, accident and emergency incident'],
#  ['society', 'environment', 'science and technology', 'politics'],
#  ['sport',
#   'human interest',
#   'economy, business and finance',
#   'arts, culture, entertainment and media'],
#  ['conflict, war and peace',
#   'religion and belief',
#   'disaster, accident and emergency incident',
#   'society'],
#  ['weather', 'society', 'human interest', 'environment'],
#  ['economy, business and finance',
#   'society',
#   'crime, law and justice',
#   'human interest'],
#  ['religion and belief',
#   'arts, culture, entertainment and media',
#   'human interest',
#   'crime, law and justice'],
#  ['health', 'sport', 'lifestyle and leisure', 'human interest'],
#  ['health', 'human interest', 'society', 'science and technology'],
#  ['politics', 'society', 'conflict, war and peace', 'human interest'],
#  ['human interest',
#   'crime, law and justice',
#   'disaster, accident and emergency incident',
#   'society'],
#  ['religion and belief', 'conflict, war and peace', 'education', 'society'],
#  ['politics', 'society', 'conflict, war and peace', 'human interest'],
#  ['crime, law and justice',
#   'religion and belief',
#   'society',
#   'conflict, war and peace'],
#  ['religion and belief',
#   'human interest',
#   'conflict, war and peace',
#   'society'],
#  ['politics', 'environment', 'society', 'human interest'],
#  ['human interest',
#   'health',
#   'science and technology',
#   'disaster, accident and emergency incident'],
#  ['sport',
#   'human interest',
#   'arts, culture, entertainment and media',
#   'health'],
#  ['politics', 'society', 'economy, business and finance', 'labour'],
#  ['human interest', 'economy, business and finance', 'society', 'politics'],
#  ['science and technology', 'human interest', 'environment', 'education'],
#  ['crime, law and justice', 'society', 'human interest', 'labour'],
#  ['environment',
#   'crime, law and justice',
#   'science and technology',
#   'society'],
#  ['society',
#   'arts, culture, entertainment and media',
#   'economy, business and finance',
#   'politics'],
#  ['human interest',
#   'arts, culture, entertainment and media',
#   'lifestyle and leisure',
#   'society'],
#  ['society', 'crime, law and justice', 'lifestyle and leisure', 'politics'],
#  ['arts, culture, entertainment and media',
#   'human interest',
#   'society',
#   'environment'],
#  ['sport',
#   'human interest',
#   'society',
#   'arts, culture, entertainment and media'],
#  ['health',
#   'science and technology',
#   'disaster, accident and emergency incident',
#   'environment'],
#  ['human interest',
#   'science and technology',
#   'society',
#   'arts, culture, entertainment and media'],
#  ['economy, business and finance',
#   'science and technology',
#   'society',
#   'politics'],
#  ['economy, business and finance',
#   'society',
#   'lifestyle and leisure',
#   'arts, culture, entertainment and media'],
#  ['conflict, war and peace', 'politics', 'society', 'crime, law and justice'],
#  ['human interest', 'conflict, war and peace', 'society', 'labour'],
#  ['sport',
#   'arts, culture, entertainment and media',
#   'science and technology',
#   'disaster, accident and emergency incident'],
#  ['crime, law and justice', 'society', 'human interest', 'politics'],
#  ['human interest', 'health', 'education', 'science and technology'],
#  ['weather',
#   'disaster, accident and emergency incident',
#   'human interest',
#   'society'],
#  ['economy, business and finance', 'labour', 'society', 'health'],
#  ['lifestyle and leisure',
#   'arts, culture, entertainment and media',
#   'environment',
#   'sport'],
#  ['environment', 'conflict, war and peace', 'politics', 'human interest'],
#  ['economy, business and finance',
#   'science and technology',
#   'disaster, accident and emergency incident',
#   'labour'],
#  ['conflict, war and peace',
#   'disaster, accident and emergency incident',
#   'politics',
#   'society'],
#  ['crime, law and justice',
#   'economy, business and finance',
#   'society',
#   'arts, culture, entertainment and media'],
#  ['health', 'environment', 'society', 'science and technology'],
#  ['economy, business and finance',
#   'society',
#   'conflict, war and peace',
#   'human interest'],
#  ['human interest', 'society', 'lifestyle and leisure', 'environment'],
#  ['science and technology', 'labour', 'human interest', 'environment'],
#  ['health', 'education', 'society', 'human interest'],
#  ['politics', 'society', 'environment', 'science and technology'],
#  ['disaster, accident and emergency incident',
#   'society',
#   'environment',
#   'crime, law and justice'],
#  ['politics',
#   'health',
#   'human interest',
#   'disaster, accident and emergency incident'],
#  ['education', 'human interest', 'labour', 'economy, business and finance'],
#  ['religion and belief', 'politics', 'conflict, war and peace', 'society'],
#  ['labour', 'politics', 'society', 'economy, business and finance'],
#  ['human interest',
#   'health',
#   'arts, culture, entertainment and media',
#   'education'],
#  ['health',
#   'politics',
#   'society',
#   'disaster, accident and emergency incident'],
#  ['science and technology',
#   'arts, culture, entertainment and media',
#   'disaster, accident and emergency incident',
#   'economy, business and finance'],
#  ['health',
#   'science and technology',
#   'environment',
#   'disaster, accident and emergency incident'],
#  ['sport', 'labour', 'environment', 'economy, business and finance'],
#  ['sport',
#   'economy, business and finance',
#   'arts, culture, entertainment and media',
#   'environment'],
#  ['religion and belief',
#   'politics',
#   'society',
#   'disaster, accident and emergency incident'],
#  ['disaster, accident and emergency incident',
#   'human interest',
#   'conflict, war and peace',
#   'environment'],
#  ['crime, law and justice',
#   'disaster, accident and emergency incident',
#   'human interest',
#   'society'],
#  ['health', 'human interest', 'society', 'environment'],
#  ['education',
#   'human interest',
#   'arts, culture, entertainment and media',
#   'environment'],
#  ['disaster, accident and emergency incident',
#   'crime, law and justice',
#   'human interest',
#   'society'],
#  ['society',
#   'politics',
#   'disaster, accident and emergency incident',
#   'health'],
#  ['health', 'society', 'human interest', 'economy, business and finance'],
#  ['crime, law and justice',
#   'society',
#   'human interest',
#   'conflict, war and peace'],
#  ['health',
#   'human interest',
#   'environment',
#   'disaster, accident and emergency incident'],
#  ['health',
#   'science and technology',
#   'human interest',
#   'lifestyle and leisure'],
#  ['sport',
#   'arts, culture, entertainment and media',
#   'lifestyle and leisure',
#   'human interest'],
#  ['society', 'crime, law and justice', 'politics', 'conflict, war and peace'],
#  ['economy, business and finance', 'society', 'health', 'human interest'],
#  ['religion and belief', 'society', 'politics', 'environment'],
#  ['disaster, accident and emergency incident',
#   'crime, law and justice',
#   'human interest',
#   'society'],
#  ['politics', 'environment', 'society', 'human interest'],
#  ['disaster, accident and emergency incident',
#   'weather',
#   'society',
#   'environment'],
#  ['sport',
#   'human interest',
#   'health',
#   'arts, culture, entertainment and media'],
#  ['politics',
#   'human interest',
#   'society',
#   'arts, culture, entertainment and media'],
#  ['weather',
#   'disaster, accident and emergency incident',
#   'society',
#   'environment'],
#  ['society', 'human interest', 'crime, law and justice', 'weather'],
#  ['crime, law and justice',
#   'conflict, war and peace',
#   'human interest',
#   'society'],
#  ['education',
#   'human interest',
#   'disaster, accident and emergency incident',
#   'society'],
#  ['sport',
#   'arts, culture, entertainment and media',
#   'economy, business and finance',
#   'human interest'],
#  ['politics',
#   'conflict, war and peace',
#   'society',
#   'disaster, accident and emergency incident'],
#  ['arts, culture, entertainment and media',
#   'economy, business and finance',
#   'society',
#   'human interest'],
#  ['politics', 'society', 'human interest', 'religion and belief'],
#  ['economy, business and finance', 'sport', 'human interest', 'environment'],
#  ['arts, culture, entertainment and media',
#   'disaster, accident and emergency incident',
#   'conflict, war and peace',
#   'society']]

# %%
df2_pred4 = find_matching_category_for_each_list(df2_pred4 , y_test)

# %%
df2_pred4
# Out:
# ['science and technology',
#  'education',
#  'lifestyle and leisure',
#  'education',
#  'arts, culture, entertainment and media',
#  'human interest',
#  'economy, business and finance',
#  'weather',
#  'society',
#  'conflict, war and peace',
#  'science and technology',
#  'sport',
#  'religion and belief',
#  'weather',
#  'society',
#  'religion and belief',
#  'lifestyle and leisure',
#  'health',
#  'politics',
#  'crime, law and justice',
#  'religion and belief',
#  'conflict, war and peace',
#  'religion and belief',
#  'religion and belief',
#  'environment',
#  'health',
#  'sport',
#  'society',
#  'politics',
#  'environment',
#  'crime, law and justice',
#  'crime, law and justice',
#  'society',
#  'society',
#  'society',
#  'society',
#  'sport',
#  'health',
#  'human interest',
#  'economy, business and finance',
#  'arts, culture, entertainment and media',
#  'conflict, war and peace',
#  'conflict, war and peace',
#  'sport',
#  'society',
#  'health',
#  'weather',
#  'labour',
#  'lifestyle and leisure',
#  'environment',
#  'economy, business and finance',
#  'conflict, war and peace',
#  'economy, business and finance',
#  'health',
#  'economy, business and finance',
#  'environment',
#  'science and technology',
#  'health',
#  'politics',
#  'disaster, accident and emergency incident',
#  'health',
#  'education',
#  'religion and belief',
#  'labour',
#  'human interest',
#  'health',
#  'science and technology',
#  'environment',
#  'sport',
#  'sport',
#  'religion and belief',
#  'human interest',
#  'disaster, accident and emergency incident',
#  'society',
#  'education',
#  'disaster, accident and emergency incident',
#  'politics',
#  'society',
#  'crime, law and justice',
#  'health',
#  'health',
#  'sport',
#  'conflict, war and peace',
#  'economy, business and finance',
#  'religion and belief',
#  'disaster, accident and emergency incident',
#  'politics',
#  'disaster, accident and emergency incident',
#  'sport',
#  'politics',
#  'weather',
#  'society',
#  'conflict, war and peace',
#  'education',
#  'sport',
#  'politics',
#  'arts, culture, entertainment and media',
#  'politics',
#  'sport',
#  'arts, culture, entertainment and media']

# %%
compute_classification_report(y_test , df2_pred4)
# Out:
#                                            precision    recall  f1-score   support
#
#    arts, culture, entertainment and media       0.50      0.67      0.57         3
#                   conflict, war and peace       1.00      1.00      1.00         7
#                    crime, law and justice       1.00      0.80      0.89         5
# disaster, accident and emergency incident       1.00      1.00      1.00         5
#             economy, business and finance       0.67      1.00      0.80         4
#                                 education       0.80      0.67      0.73         6
#                               environment       1.00      0.83      0.91         6
#                                    health       0.60      1.00      0.75         6
#                            human interest       0.75      0.60      0.67         5
#                                    labour       1.00      0.33      0.50         6
#                     lifestyle and leisure       0.67      0.67      0.67         3
#                                  politics       0.88      0.88      0.88         8
#                       religion and belief       0.88      1.00      0.93         7
#                    science and technology       1.00      0.57      0.73         7
#                                   society       0.82      0.90      0.86        10
#                                     sport       0.80      1.00      0.89         8
#                                   weather       1.00      1.00      1.00         4
#
#                                  accuracy                           0.83       100
#                                 macro avg       0.84      0.82      0.81       100
#                              weighted avg       0.86      0.83      0.82       100
# 0.83

# %% [markdown]
# # **5**

# %%
df2_pred5 = find_top_categories_for_lists(doc_prb , 5)

# %%
df2_pred5
# Out:
# [['science and technology',
#   'society',
#   'education',
#   'human interest',
#   'lifestyle and leisure'],
#  ['education',
#   'religion and belief',
#   'society',
#   'human interest',
#   'lifestyle and leisure'],
#  ['lifestyle and leisure',
#   'arts, culture, entertainment and media',
#   'health',
#   'environment',
#   'labour'],
#  ['education',
#   'human interest',
#   'science and technology',
#   'health',
#   'society'],
#  ['arts, culture, entertainment and media',
#   'sport',
#   'society',
#   'lifestyle and leisure',
#   'science and technology'],
#  ['human interest',
#   'lifestyle and leisure',
#   'arts, culture, entertainment and media',
#   'health',
#   'conflict, war and peace'],
#  ['economy, business and finance',
#   'society',
#   'politics',
#   'human interest',
#   'labour'],
#  ['disaster, accident and emergency incident',
#   'weather',
#   'society',
#   'human interest',
#   'environment'],
#  ['politics',
#   'society',
#   'religion and belief',
#   'human interest',
#   'conflict, war and peace'],
#  ['conflict, war and peace',
#   'politics',
#   'society',
#   'disaster, accident and emergency incident',
#   'human interest'],
#  ['society', 'environment', 'science and technology', 'politics', 'labour'],
#  ['sport',
#   'human interest',
#   'economy, business and finance',
#   'arts, culture, entertainment and media',
#   'society'],
#  ['conflict, war and peace',
#   'religion and belief',
#   'disaster, accident and emergency incident',
#   'society',
#   'politics'],
#  ['weather',
#   'society',
#   'human interest',
#   'environment',
#   'disaster, accident and emergency incident'],
#  ['economy, business and finance',
#   'society',
#   'crime, law and justice',
#   'human interest',
#   'conflict, war and peace'],
#  ['religion and belief',
#   'arts, culture, entertainment and media',
#   'human interest',
#   'crime, law and justice',
#   'society'],
#  ['health',
#   'sport',
#   'lifestyle and leisure',
#   'human interest',
#   'arts, culture, entertainment and media'],
#  ['health',
#   'human interest',
#   'society',
#   'science and technology',
#   'environment'],
#  ['politics',
#   'society',
#   'conflict, war and peace',
#   'human interest',
#   'disaster, accident and emergency incident'],
#  ['human interest',
#   'crime, law and justice',
#   'disaster, accident and emergency incident',
#   'society',
#   'arts, culture, entertainment and media'],
#  ['religion and belief',
#   'conflict, war and peace',
#   'education',
#   'society',
#   'disaster, accident and emergency incident'],
#  ['politics',
#   'society',
#   'conflict, war and peace',
#   'human interest',
#   'labour'],
#  ['crime, law and justice',
#   'religion and belief',
#   'society',
#   'conflict, war and peace',
#   'human interest'],
#  ['religion and belief',
#   'human interest',
#   'conflict, war and peace',
#   'society',
#   'crime, law and justice'],
#  ['politics',
#   'environment',
#   'society',
#   'human interest',
#   'conflict, war and peace'],
#  ['human interest',
#   'health',
#   'science and technology',
#   'disaster, accident and emergency incident',
#   'society'],
#  ['sport',
#   'human interest',
#   'arts, culture, entertainment and media',
#   'health',
#   'economy, business and finance'],
#  ['politics',
#   'society',
#   'economy, business and finance',
#   'labour',
#   'conflict, war and peace'],
#  ['human interest',
#   'economy, business and finance',
#   'society',
#   'politics',
#   'arts, culture, entertainment and media'],
#  ['science and technology',
#   'human interest',
#   'environment',
#   'education',
#   'disaster, accident and emergency incident'],
#  ['crime, law and justice', 'society', 'human interest', 'labour', 'politics'],
#  ['environment',
#   'crime, law and justice',
#   'science and technology',
#   'society',
#   'disaster, accident and emergency incident'],
#  ['society',
#   'arts, culture, entertainment and media',
#   'economy, business and finance',
#   'politics',
#   'human interest'],
#  ['human interest',
#   'arts, culture, entertainment and media',
#   'lifestyle and leisure',
#   'society',
#   'education'],
#  ['society',
#   'crime, law and justice',
#   'lifestyle and leisure',
#   'politics',
#   'human interest'],
#  ['arts, culture, entertainment and media',
#   'human interest',
#   'society',
#   'environment',
#   'lifestyle and leisure'],
#  ['sport',
#   'human interest',
#   'society',
#   'arts, culture, entertainment and media',
#   'economy, business and finance'],
#  ['health',
#   'science and technology',
#   'disaster, accident and emergency incident',
#   'environment',
#   'society'],
#  ['human interest',
#   'science and technology',
#   'society',
#   'arts, culture, entertainment and media',
#   'labour'],
#  ['economy, business and finance',
#   'science and technology',
#   'society',
#   'politics',
#   'human interest'],
#  ['economy, business and finance',
#   'society',
#   'lifestyle and leisure',
#   'arts, culture, entertainment and media',
#   'weather'],
#  ['conflict, war and peace',
#   'politics',
#   'society',
#   'crime, law and justice',
#   'human interest'],
#  ['human interest', 'conflict, war and peace', 'society', 'labour', 'health'],
#  ['sport',
#   'arts, culture, entertainment and media',
#   'science and technology',
#   'disaster, accident and emergency incident',
#   'environment'],
#  ['crime, law and justice',
#   'society',
#   'human interest',
#   'politics',
#   'conflict, war and peace'],
#  ['human interest',
#   'health',
#   'education',
#   'science and technology',
#   'disaster, accident and emergency incident'],
#  ['weather',
#   'disaster, accident and emergency incident',
#   'human interest',
#   'society',
#   'environment'],
#  ['economy, business and finance',
#   'labour',
#   'society',
#   'health',
#   'disaster, accident and emergency incident'],
#  ['lifestyle and leisure',
#   'arts, culture, entertainment and media',
#   'environment',
#   'sport',
#   'disaster, accident and emergency incident'],
#  ['environment',
#   'conflict, war and peace',
#   'politics',
#   'human interest',
#   'society'],
#  ['economy, business and finance',
#   'science and technology',
#   'disaster, accident and emergency incident',
#   'labour',
#   'crime, law and justice'],
#  ['conflict, war and peace',
#   'disaster, accident and emergency incident',
#   'politics',
#   'society',
#   'human interest'],
#  ['crime, law and justice',
#   'economy, business and finance',
#   'society',
#   'arts, culture, entertainment and media',
#   'environment'],
#  ['health',
#   'environment',
#   'society',
#   'science and technology',
#   'disaster, accident and emergency incident'],
#  ['economy, business and finance',
#   'society',
#   'conflict, war and peace',
#   'human interest',
#   'health'],
#  ['human interest',
#   'society',
#   'lifestyle and leisure',
#   'environment',
#   'arts, culture, entertainment and media'],
#  ['science and technology',
#   'labour',
#   'human interest',
#   'environment',
#   'society'],
#  ['health',
#   'education',
#   'society',
#   'human interest',
#   'crime, law and justice'],
#  ['politics',
#   'society',
#   'environment',
#   'science and technology',
#   'human interest'],
#  ['disaster, accident and emergency incident',
#   'society',
#   'environment',
#   'crime, law and justice',
#   'labour'],
#  ['politics',
#   'health',
#   'human interest',
#   'disaster, accident and emergency incident',
#   'society'],
#  ['education',
#   'human interest',
#   'labour',
#   'economy, business and finance',
#   'society'],
#  ['religion and belief',
#   'politics',
#   'conflict, war and peace',
#   'society',
#   'disaster, accident and emergency incident'],
#  ['labour',
#   'politics',
#   'society',
#   'economy, business and finance',
#   'human interest'],
#  ['human interest',
#   'health',
#   'arts, culture, entertainment and media',
#   'education',
#   'society'],
#  ['health',
#   'politics',
#   'society',
#   'disaster, accident and emergency incident',
#   'human interest'],
#  ['science and technology',
#   'arts, culture, entertainment and media',
#   'disaster, accident and emergency incident',
#   'economy, business and finance',
#   'environment'],
#  ['health',
#   'science and technology',
#   'environment',
#   'disaster, accident and emergency incident',
#   'human interest'],
#  ['sport',
#   'labour',
#   'environment',
#   'economy, business and finance',
#   'arts, culture, entertainment and media'],
#  ['sport',
#   'economy, business and finance',
#   'arts, culture, entertainment and media',
#   'environment',
#   'society'],
#  ['religion and belief',
#   'politics',
#   'society',
#   'disaster, accident and emergency incident',
#   'human interest'],
#  ['disaster, accident and emergency incident',
#   'human interest',
#   'conflict, war and peace',
#   'environment',
#   'society'],
#  ['crime, law and justice',
#   'disaster, accident and emergency incident',
#   'human interest',
#   'society',
#   'health'],
#  ['health',
#   'human interest',
#   'society',
#   'environment',
#   'science and technology'],
#  ['education',
#   'human interest',
#   'arts, culture, entertainment and media',
#   'environment',
#   'society'],
#  ['disaster, accident and emergency incident',
#   'crime, law and justice',
#   'human interest',
#   'society',
#   'health'],
#  ['society',
#   'politics',
#   'disaster, accident and emergency incident',
#   'health',
#   'economy, business and finance'],
#  ['health',
#   'society',
#   'human interest',
#   'economy, business and finance',
#   'lifestyle and leisure'],
#  ['crime, law and justice',
#   'society',
#   'human interest',
#   'conflict, war and peace',
#   'economy, business and finance'],
#  ['health',
#   'human interest',
#   'environment',
#   'disaster, accident and emergency incident',
#   'science and technology'],
#  ['health',
#   'science and technology',
#   'human interest',
#   'lifestyle and leisure',
#   'society'],
#  ['sport',
#   'arts, culture, entertainment and media',
#   'lifestyle and leisure',
#   'human interest',
#   'society'],
#  ['society',
#   'crime, law and justice',
#   'politics',
#   'conflict, war and peace',
#   'human interest'],
#  ['economy, business and finance',
#   'society',
#   'health',
#   'human interest',
#   'science and technology'],
#  ['religion and belief',
#   'society',
#   'politics',
#   'environment',
#   'human interest'],
#  ['disaster, accident and emergency incident',
#   'crime, law and justice',
#   'human interest',
#   'society',
#   'environment'],
#  ['politics', 'environment', 'society', 'human interest', 'education'],
#  ['disaster, accident and emergency incident',
#   'weather',
#   'society',
#   'environment',
#   'human interest'],
#  ['sport',
#   'human interest',
#   'health',
#   'arts, culture, entertainment and media',
#   'environment'],
#  ['politics',
#   'human interest',
#   'society',
#   'arts, culture, entertainment and media',
#   'economy, business and finance'],
#  ['weather',
#   'disaster, accident and emergency incident',
#   'society',
#   'environment',
#   'lifestyle and leisure'],
#  ['society',
#   'human interest',
#   'crime, law and justice',
#   'weather',
#   'politics'],
#  ['crime, law and justice',
#   'conflict, war and peace',
#   'human interest',
#   'society',
#   'environment'],
#  ['education',
#   'human interest',
#   'disaster, accident and emergency incident',
#   'society',
#   'crime, law and justice'],
#  ['sport',
#   'arts, culture, entertainment and media',
#   'economy, business and finance',
#   'human interest',
#   'society'],
#  ['politics',
#   'conflict, war and peace',
#   'society',
#   'disaster, accident and emergency incident',
#   'religion and belief'],
#  ['arts, culture, entertainment and media',
#   'economy, business and finance',
#   'society',
#   'human interest',
#   'environment'],
#  ['politics',
#   'society',
#   'human interest',
#   'religion and belief',
#   'lifestyle and leisure'],
#  ['economy, business and finance',
#   'sport',
#   'human interest',
#   'environment',
#   'conflict, war and peace'],
#  ['arts, culture, entertainment and media',
#   'disaster, accident and emergency incident',
#   'conflict, war and peace',
#   'society',
#   'politics']]

# %%
df2_pred5 = find_matching_category_for_each_list(df2_pred5 , y_test)

# %%
df2_pred5
# Out:
# ['science and technology',
#  'education',
#  'lifestyle and leisure',
#  'education',
#  'arts, culture, entertainment and media',
#  'human interest',
#  'labour',
#  'weather',
#  'society',
#  'conflict, war and peace',
#  'science and technology',
#  'sport',
#  'religion and belief',
#  'weather',
#  'society',
#  'religion and belief',
#  'lifestyle and leisure',
#  'health',
#  'politics',
#  'crime, law and justice',
#  'religion and belief',
#  'conflict, war and peace',
#  'religion and belief',
#  'religion and belief',
#  'environment',
#  'health',
#  'sport',
#  'society',
#  'politics',
#  'environment',
#  'crime, law and justice',
#  'crime, law and justice',
#  'society',
#  'society',
#  'society',
#  'society',
#  'sport',
#  'health',
#  'human interest',
#  'economy, business and finance',
#  'arts, culture, entertainment and media',
#  'conflict, war and peace',
#  'conflict, war and peace',
#  'sport',
#  'society',
#  'health',
#  'weather',
#  'labour',
#  'lifestyle and leisure',
#  'environment',
#  'economy, business and finance',
#  'conflict, war and peace',
#  'economy, business and finance',
#  'health',
#  'economy, business and finance',
#  'environment',
#  'science and technology',
#  'crime, law and justice',
#  'politics',
#  'disaster, accident and emergency incident',
#  'health',
#  'education',
#  'religion and belief',
#  'labour',
#  'human interest',
#  'health',
#  'science and technology',
#  'environment',
#  'sport',
#  'sport',
#  'religion and belief',
#  'human interest',
#  'disaster, accident and emergency incident',
#  'society',
#  'education',
#  'disaster, accident and emergency incident',
#  'politics',
#  'society',
#  'crime, law and justice',
#  'health',
#  'health',
#  'sport',
#  'conflict, war and peace',
#  'economy, business and finance',
#  'religion and belief',
#  'disaster, accident and emergency incident',
#  'education',
#  'disaster, accident and emergency incident',
#  'sport',
#  'politics',
#  'weather',
#  'politics',
#  'conflict, war and peace',
#  'education',
#  'sport',
#  'politics',
#  'arts, culture, entertainment and media',
#  'politics',
#  'sport',
#  'arts, culture, entertainment and media']

# %%
compute_classification_report(y_test , df2_pred5)
# Out:
#                                            precision    recall  f1-score   support
#
#    arts, culture, entertainment and media       0.50      0.67      0.57         3
#                   conflict, war and peace       1.00      1.00      1.00         7
#                    crime, law and justice       1.00      1.00      1.00         5
# disaster, accident and emergency incident       1.00      1.00      1.00         5
#             economy, business and finance       0.80      1.00      0.89         4
#                                 education       0.83      0.83      0.83         6
#                               environment       1.00      0.83      0.91         6
#                                    health       0.67      1.00      0.80         6
#                            human interest       0.75      0.60      0.67         5
#                                    labour       1.00      0.50      0.67         6
#                     lifestyle and leisure       0.67      0.67      0.67         3
#                                  politics       1.00      1.00      1.00         8
#                       religion and belief       0.88      1.00      0.93         7
#                    science and technology       1.00      0.57      0.73         7
#                                   society       0.90      0.90      0.90        10
#                                     sport       0.80      1.00      0.89         8
#                                   weather       1.00      1.00      1.00         4
#
#                                  accuracy                           0.87       100
#                                 macro avg       0.87      0.86      0.85       100
#                              weighted avg       0.89      0.87      0.87       100
# 0.87

# %% [markdown]
# # **6**

# %%
df2_pred6 = find_top_categories_for_lists(doc_prb , 6)

# %%
df2_pred6
# Out:
# [['science and technology',
#   'society',
#   'education',
#   'human interest',
#   'lifestyle and leisure',
#   'labour'],
#  ['education',
#   'religion and belief',
#   'society',
#   'human interest',
#   'lifestyle and leisure',
#   'economy, business and finance'],
#  ['lifestyle and leisure',
#   'arts, culture, entertainment and media',
#   'health',
#   'environment',
#   'labour',
#   'society'],
#  ['education',
#   'human interest',
#   'science and technology',
#   'health',
#   'society',
#   'labour'],
#  ['arts, culture, entertainment and media',
#   'sport',
#   'society',
#   'lifestyle and leisure',
#   'science and technology',
#   'human interest'],
#  ['human interest',
#   'lifestyle and leisure',
#   'arts, culture, entertainment and media',
#   'health',
#   'conflict, war and peace',
#   'science and technology'],
#  ['economy, business and finance',
#   'society',
#   'politics',
#   'human interest',
#   'labour',
#   'crime, law and justice'],
#  ['disaster, accident and emergency incident',
#   'weather',
#   'society',
#   'human interest',
#   'environment',
#   'economy, business and finance'],
#  ['politics',
#   'society',
#   'religion and belief',
#   'human interest',
#   'conflict, war and peace',
#   'arts, culture, entertainment and media'],
#  ['conflict, war and peace',
#   'politics',
#   'society',
#   'disaster, accident and emergency incident',
#   'human interest',
#   'crime, law and justice'],
#  ['society',
#   'environment',
#   'science and technology',
#   'politics',
#   'labour',
#   'human interest'],
#  ['sport',
#   'human interest',
#   'economy, business and finance',
#   'arts, culture, entertainment and media',
#   'society',
#   'education'],
#  ['conflict, war and peace',
#   'religion and belief',
#   'disaster, accident and emergency incident',
#   'society',
#   'politics',
#   'crime, law and justice'],
#  ['weather',
#   'society',
#   'human interest',
#   'environment',
#   'disaster, accident and emergency incident',
#   'science and technology'],
#  ['economy, business and finance',
#   'society',
#   'crime, law and justice',
#   'human interest',
#   'conflict, war and peace',
#   'politics'],
#  ['religion and belief',
#   'arts, culture, entertainment and media',
#   'human interest',
#   'crime, law and justice',
#   'society',
#   'lifestyle and leisure'],
#  ['health',
#   'sport',
#   'lifestyle and leisure',
#   'human interest',
#   'arts, culture, entertainment and media',
#   'labour'],
#  ['health',
#   'human interest',
#   'society',
#   'science and technology',
#   'environment',
#   'lifestyle and leisure'],
#  ['politics',
#   'society',
#   'conflict, war and peace',
#   'human interest',
#   'disaster, accident and emergency incident',
#   'labour'],
#  ['human interest',
#   'crime, law and justice',
#   'disaster, accident and emergency incident',
#   'society',
#   'arts, culture, entertainment and media',
#   'conflict, war and peace'],
#  ['religion and belief',
#   'conflict, war and peace',
#   'education',
#   'society',
#   'disaster, accident and emergency incident',
#   'human interest'],
#  ['politics',
#   'society',
#   'conflict, war and peace',
#   'human interest',
#   'labour',
#   'economy, business and finance'],
#  ['crime, law and justice',
#   'religion and belief',
#   'society',
#   'conflict, war and peace',
#   'human interest',
#   'disaster, accident and emergency incident'],
#  ['religion and belief',
#   'human interest',
#   'conflict, war and peace',
#   'society',
#   'crime, law and justice',
#   'arts, culture, entertainment and media'],
#  ['politics',
#   'environment',
#   'society',
#   'human interest',
#   'conflict, war and peace',
#   'science and technology'],
#  ['human interest',
#   'health',
#   'science and technology',
#   'disaster, accident and emergency incident',
#   'society',
#   'crime, law and justice'],
#  ['sport',
#   'human interest',
#   'arts, culture, entertainment and media',
#   'health',
#   'economy, business and finance',
#   'lifestyle and leisure'],
#  ['politics',
#   'society',
#   'economy, business and finance',
#   'labour',
#   'conflict, war and peace',
#   'human interest'],
#  ['human interest',
#   'economy, business and finance',
#   'society',
#   'politics',
#   'arts, culture, entertainment and media',
#   'crime, law and justice'],
#  ['science and technology',
#   'human interest',
#   'environment',
#   'education',
#   'disaster, accident and emergency incident',
#   'sport'],
#  ['crime, law and justice',
#   'society',
#   'human interest',
#   'labour',
#   'politics',
#   'conflict, war and peace'],
#  ['environment',
#   'crime, law and justice',
#   'science and technology',
#   'society',
#   'disaster, accident and emergency incident',
#   'human interest'],
#  ['society',
#   'arts, culture, entertainment and media',
#   'economy, business and finance',
#   'politics',
#   'human interest',
#   'science and technology'],
#  ['human interest',
#   'arts, culture, entertainment and media',
#   'lifestyle and leisure',
#   'society',
#   'education',
#   'crime, law and justice'],
#  ['society',
#   'crime, law and justice',
#   'lifestyle and leisure',
#   'politics',
#   'human interest',
#   'sport'],
#  ['arts, culture, entertainment and media',
#   'human interest',
#   'society',
#   'environment',
#   'lifestyle and leisure',
#   'science and technology'],
#  ['sport',
#   'human interest',
#   'society',
#   'arts, culture, entertainment and media',
#   'economy, business and finance',
#   'politics'],
#  ['health',
#   'science and technology',
#   'disaster, accident and emergency incident',
#   'environment',
#   'society',
#   'arts, culture, entertainment and media'],
#  ['human interest',
#   'science and technology',
#   'society',
#   'arts, culture, entertainment and media',
#   'labour',
#   'environment'],
#  ['economy, business and finance',
#   'science and technology',
#   'society',
#   'politics',
#   'human interest',
#   'labour'],
#  ['economy, business and finance',
#   'society',
#   'lifestyle and leisure',
#   'arts, culture, entertainment and media',
#   'weather',
#   'human interest'],
#  ['conflict, war and peace',
#   'politics',
#   'society',
#   'crime, law and justice',
#   'human interest',
#   'labour'],
#  ['human interest',
#   'conflict, war and peace',
#   'society',
#   'labour',
#   'health',
#   'politics'],
#  ['sport',
#   'arts, culture, entertainment and media',
#   'science and technology',
#   'disaster, accident and emergency incident',
#   'environment',
#   'society'],
#  ['crime, law and justice',
#   'society',
#   'human interest',
#   'politics',
#   'conflict, war and peace',
#   'weather'],
#  ['human interest',
#   'health',
#   'education',
#   'science and technology',
#   'disaster, accident and emergency incident',
#   'society'],
#  ['weather',
#   'disaster, accident and emergency incident',
#   'human interest',
#   'society',
#   'environment',
#   'health'],
#  ['economy, business and finance',
#   'labour',
#   'society',
#   'health',
#   'disaster, accident and emergency incident',
#   'human interest'],
#  ['lifestyle and leisure',
#   'arts, culture, entertainment and media',
#   'environment',
#   'sport',
#   'disaster, accident and emergency incident',
#   'economy, business and finance'],
#  ['environment',
#   'conflict, war and peace',
#   'politics',
#   'human interest',
#   'society',
#   'health'],
#  ['economy, business and finance',
#   'science and technology',
#   'disaster, accident and emergency incident',
#   'labour',
#   'crime, law and justice',
#   'society'],
#  ['conflict, war and peace',
#   'disaster, accident and emergency incident',
#   'politics',
#   'society',
#   'human interest',
#   'crime, law and justice'],
#  ['crime, law and justice',
#   'economy, business and finance',
#   'society',
#   'arts, culture, entertainment and media',
#   'environment',
#   'labour'],
#  ['health',
#   'environment',
#   'society',
#   'science and technology',
#   'disaster, accident and emergency incident',
#   'lifestyle and leisure'],
#  ['economy, business and finance',
#   'society',
#   'conflict, war and peace',
#   'human interest',
#   'health',
#   'crime, law and justice'],
#  ['human interest',
#   'society',
#   'lifestyle and leisure',
#   'environment',
#   'arts, culture, entertainment and media',
#   'economy, business and finance'],
#  ['science and technology',
#   'labour',
#   'human interest',
#   'environment',
#   'society',
#   'arts, culture, entertainment and media'],
#  ['health',
#   'education',
#   'society',
#   'human interest',
#   'crime, law and justice',
#   'science and technology'],
#  ['politics',
#   'society',
#   'environment',
#   'science and technology',
#   'human interest',
#   'conflict, war and peace'],
#  ['disaster, accident and emergency incident',
#   'society',
#   'environment',
#   'crime, law and justice',
#   'labour',
#   'human interest'],
#  ['politics',
#   'health',
#   'human interest',
#   'disaster, accident and emergency incident',
#   'society',
#   'economy, business and finance'],
#  ['education',
#   'human interest',
#   'labour',
#   'economy, business and finance',
#   'society',
#   'arts, culture, entertainment and media'],
#  ['religion and belief',
#   'politics',
#   'conflict, war and peace',
#   'society',
#   'disaster, accident and emergency incident',
#   'human interest'],
#  ['labour',
#   'politics',
#   'society',
#   'economy, business and finance',
#   'human interest',
#   'crime, law and justice'],
#  ['human interest',
#   'health',
#   'arts, culture, entertainment and media',
#   'education',
#   'society',
#   'crime, law and justice'],
#  ['health',
#   'politics',
#   'society',
#   'disaster, accident and emergency incident',
#   'human interest',
#   'crime, law and justice'],
#  ['science and technology',
#   'arts, culture, entertainment and media',
#   'disaster, accident and emergency incident',
#   'economy, business and finance',
#   'environment',
#   'conflict, war and peace'],
#  ['health',
#   'science and technology',
#   'environment',
#   'disaster, accident and emergency incident',
#   'human interest',
#   'lifestyle and leisure'],
#  ['sport',
#   'labour',
#   'environment',
#   'economy, business and finance',
#   'arts, culture, entertainment and media',
#   'society'],
#  ['sport',
#   'economy, business and finance',
#   'arts, culture, entertainment and media',
#   'environment',
#   'society',
#   'lifestyle and leisure'],
#  ['religion and belief',
#   'politics',
#   'society',
#   'disaster, accident and emergency incident',
#   'human interest',
#   'conflict, war and peace'],
#  ['disaster, accident and emergency incident',
#   'human interest',
#   'conflict, war and peace',
#   'environment',
#   'society',
#   'arts, culture, entertainment and media'],
#  ['crime, law and justice',
#   'disaster, accident and emergency incident',
#   'human interest',
#   'society',
#   'health',
#   'conflict, war and peace'],
#  ['health',
#   'human interest',
#   'society',
#   'environment',
#   'science and technology',
#   'disaster, accident and emergency incident'],
#  ['education',
#   'human interest',
#   'arts, culture, entertainment and media',
#   'environment',
#   'society',
#   'lifestyle and leisure'],
#  ['disaster, accident and emergency incident',
#   'crime, law and justice',
#   'human interest',
#   'society',
#   'health',
#   'arts, culture, entertainment and media'],
#  ['society',
#   'politics',
#   'disaster, accident and emergency incident',
#   'health',
#   'economy, business and finance',
#   'human interest'],
#  ['health',
#   'society',
#   'human interest',
#   'economy, business and finance',
#   'lifestyle and leisure',
#   'science and technology'],
#  ['crime, law and justice',
#   'society',
#   'human interest',
#   'conflict, war and peace',
#   'economy, business and finance',
#   'science and technology'],
#  ['health',
#   'human interest',
#   'environment',
#   'disaster, accident and emergency incident',
#   'science and technology',
#   'labour'],
#  ['health',
#   'science and technology',
#   'human interest',
#   'lifestyle and leisure',
#   'society',
#   'education'],
#  ['sport',
#   'arts, culture, entertainment and media',
#   'lifestyle and leisure',
#   'human interest',
#   'society',
#   'labour'],
#  ['society',
#   'crime, law and justice',
#   'politics',
#   'conflict, war and peace',
#   'human interest',
#   'labour'],
#  ['economy, business and finance',
#   'society',
#   'health',
#   'human interest',
#   'science and technology',
#   'arts, culture, entertainment and media'],
#  ['religion and belief',
#   'society',
#   'politics',
#   'environment',
#   'human interest',
#   'conflict, war and peace'],
#  ['disaster, accident and emergency incident',
#   'crime, law and justice',
#   'human interest',
#   'society',
#   'environment',
#   'health'],
#  ['politics',
#   'environment',
#   'society',
#   'human interest',
#   'education',
#   'conflict, war and peace'],
#  ['disaster, accident and emergency incident',
#   'weather',
#   'society',
#   'environment',
#   'human interest',
#   'conflict, war and peace'],
#  ['sport',
#   'human interest',
#   'health',
#   'arts, culture, entertainment and media',
#   'environment',
#   'labour'],
#  ['politics',
#   'human interest',
#   'society',
#   'arts, culture, entertainment and media',
#   'economy, business and finance',
#   'conflict, war and peace'],
#  ['weather',
#   'disaster, accident and emergency incident',
#   'society',
#   'environment',
#   'lifestyle and leisure',
#   'health'],
#  ['society',
#   'human interest',
#   'crime, law and justice',
#   'weather',
#   'politics',
#   'economy, business and finance'],
#  ['crime, law and justice',
#   'conflict, war and peace',
#   'human interest',
#   'society',
#   'environment',
#   'health'],
#  ['education',
#   'human interest',
#   'disaster, accident and emergency incident',
#   'society',
#   'crime, law and justice',
#   'conflict, war and peace'],
#  ['sport',
#   'arts, culture, entertainment and media',
#   'economy, business and finance',
#   'human interest',
#   'society',
#   'lifestyle and leisure'],
#  ['politics',
#   'conflict, war and peace',
#   'society',
#   'disaster, accident and emergency incident',
#   'religion and belief',
#   'crime, law and justice'],
#  ['arts, culture, entertainment and media',
#   'economy, business and finance',
#   'society',
#   'human interest',
#   'environment',
#   'conflict, war and peace'],
#  ['politics',
#   'society',
#   'human interest',
#   'religion and belief',
#   'lifestyle and leisure',
#   'conflict, war and peace'],
#  ['economy, business and finance',
#   'sport',
#   'human interest',
#   'environment',
#   'conflict, war and peace',
#   'crime, law and justice'],
#  ['arts, culture, entertainment and media',
#   'disaster, accident and emergency incident',
#   'conflict, war and peace',
#   'society',
#   'politics',
#   'environment']]

# %%
df2_pred6 = find_matching_category_for_each_list(df2_pred6 , y_test)

# %%
df2_pred6
# Out:
# ['science and technology',
#  'education',
#  'lifestyle and leisure',
#  'education',
#  'arts, culture, entertainment and media',
#  'human interest',
#  'labour',
#  'weather',
#  'society',
#  'conflict, war and peace',
#  'science and technology',
#  'sport',
#  'religion and belief',
#  'weather',
#  'society',
#  'religion and belief',
#  'lifestyle and leisure',
#  'health',
#  'politics',
#  'crime, law and justice',
#  'religion and belief',
#  'conflict, war and peace',
#  'religion and belief',
#  'religion and belief',
#  'environment',
#  'health',
#  'sport',
#  'society',
#  'politics',
#  'environment',
#  'crime, law and justice',
#  'crime, law and justice',
#  'society',
#  'society',
#  'society',
#  'society',
#  'sport',
#  'health',
#  'human interest',
#  'economy, business and finance',
#  'arts, culture, entertainment and media',
#  'conflict, war and peace',
#  'conflict, war and peace',
#  'sport',
#  'society',
#  'health',
#  'weather',
#  'labour',
#  'lifestyle and leisure',
#  'environment',
#  'economy, business and finance',
#  'conflict, war and peace',
#  'economy, business and finance',
#  'health',
#  'economy, business and finance',
#  'environment',
#  'science and technology',
#  'crime, law and justice',
#  'politics',
#  'disaster, accident and emergency incident',
#  'health',
#  'education',
#  'religion and belief',
#  'labour',
#  'human interest',
#  'health',
#  'science and technology',
#  'environment',
#  'sport',
#  'sport',
#  'religion and belief',
#  'human interest',
#  'disaster, accident and emergency incident',
#  'society',
#  'education',
#  'disaster, accident and emergency incident',
#  'politics',
#  'society',
#  'crime, law and justice',
#  'health',
#  'health',
#  'sport',
#  'conflict, war and peace',
#  'economy, business and finance',
#  'religion and belief',
#  'disaster, accident and emergency incident',
#  'education',
#  'disaster, accident and emergency incident',
#  'labour',
#  'politics',
#  'weather',
#  'politics',
#  'conflict, war and peace',
#  'education',
#  'sport',
#  'politics',
#  'arts, culture, entertainment and media',
#  'politics',
#  'sport',
#  'arts, culture, entertainment and media']

# %%
compute_classification_report(y_test , df2_pred6)
# Out:
#                                            precision    recall  f1-score   support
#
#    arts, culture, entertainment and media       0.50      0.67      0.57         3
#                   conflict, war and peace       1.00      1.00      1.00         7
#                    crime, law and justice       1.00      1.00      1.00         5
# disaster, accident and emergency incident       1.00      1.00      1.00         5
#             economy, business and finance       0.80      1.00      0.89         4
#                                 education       0.83      0.83      0.83         6
#                               environment       1.00      0.83      0.91         6
#                                    health       0.67      1.00      0.80         6
#                            human interest       0.75      0.60      0.67         5
#                                    labour       1.00      0.67      0.80         6
#                     lifestyle and leisure       0.67      0.67      0.67         3
#                                  politics       1.00      1.00      1.00         8
#                       religion and belief       0.88      1.00      0.93         7
#                    science and technology       1.00      0.57      0.73         7
#                                   society       0.90      0.90      0.90        10
#                                     sport       0.89      1.00      0.94         8
#                                   weather       1.00      1.00      1.00         4
#
#                                  accuracy                           0.88       100
#                                 macro avg       0.88      0.87      0.86       100
#                              weighted avg       0.90      0.88      0.88       100
# 0.88
